# %% [markdown]
# # Assignment 1
#
# ### I managed to make a notebook now :)

# %%
1 + 1
# Out:
# 2

# %%
print("this is text in a jupyter notebook")
# Out:
# this is text in a jupyter notebook

# %% [markdown]
# **bold text**
#
# _italics text_

# %% [markdown]
# now I also learned to do emojis!!! 😍😍😍😍👌🙌😂😁👍

# %% [markdown]
# and gifs!!! (❁´◡`❁)😲🥶![SoExcited~GIF.gif](attachment:1a7abbbd-3034-4320-84d5-230a4c91bf70.gif)
